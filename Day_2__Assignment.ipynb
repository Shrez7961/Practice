# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrez7961/Practice/blob/main/Day_2__Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PYTHON**

# %% [markdown]
# ## 1. Write a program in Python for, In a array 1-100 multiple numbers are duplicates, How do you find it?
#
# ![image.png](data:image/png;base64,...)

# %%
# Write Your Code Here
#Lets create a snippet to generate array by user input
import numpy as np
x=int(input('Please enter the size of array:\n'))
arr= np.random.randint(1,x,size = (1,x))
print(arr)

#Converting array to list
arr_list = arr[0].tolist()
my_dict = {}
count = []

#Creating a snippet to check how many times an element is repeated in an array
for i in set(arr_list):
  my_dict[i]=arr_list.count(i)
print(my_dict)
for keys,vals in my_dict.items():
  if vals > 1:
    print(f'The number {keys} is repeated {vals} times in the array')
# Out:
# Please enter the size of array:
# 10
# [[8 7 6 8 9 6 2 1 4 9]]
# {1: 1, 2: 1, 4: 1, 6: 2, 7: 1, 8: 2, 9: 2}
# The number 6 is repeated 2 times in the array
# The number 8 is repeated 2 times in the array
# The number 9 is repeated 2 times in the array

# %% [markdown]
# ## 2. Write a program in Python to remove duplicate elements form array.
#
# ![image.png](data:image/png;base64,...)

# %%
# Write Your Code Here
#Lets create a snippet to generate array by user input
import numpy as np
x=int(input('Please enter the size of array:\n'))
arr= np.random.randint(1,x,size = (1,x))
print(arr)
#Converting array to list
arr_list = arr[0].tolist()

#Removing duplicates from array
unique_elements = list(set(arr_list))
unique_elements_array = np.array(unique_elements)
print(f"The array after removing duplicates is {unique_elements_array}")
# Out:
# Please enter the size of array:
# 10
# [[1 2 4 5 3 8 4 1 5 4]]
# The array after removing duplicates is [1 2 3 4 5 8]

# %% [markdown]
# # **SQL**

# %% [markdown]
# ## 3. From the following Dataframes, write a SQL query to find those customers who never ordered anything. Return customer name.
#
# **Create DataFrame 1: customers**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Create Dataframe 2: orders**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Expected Output:**
#
# ![image.png](data:image/png;base64,...)

# %%
# Install SQlite & Pandasql
# !pip install db-sqlite3
# !pip install pandasql

# Importing Libraries
import pandas as pd
import sqlite3
from pandasql import sqldf
mysql = lambda q: sqldf(q, globals())


# Connection to DataBase
conn = sqlite3.connect('test2_database') 
c = conn.cursor()


# Create table
c.execute('''DROP TABLE IF EXISTS customers;''')

c.execute('''CREATE TABLE customers (
[customer_id] INTEGER,
[customer_name]  VARCHAR);''')


          
# Insert data into table          
c.execute('''INSERT INTO customers (customer_id, customer_name) VALUES ('101', 'Liam');''') 
c.execute('''INSERT INTO customers (customer_id, customer_name) VALUES ('102', 'Josh');''') 
c.execute('''INSERT INTO customers (customer_id, customer_name) VALUES ('103', 'Sean');''') 
c.execute('''INSERT INTO customers (customer_id, customer_name) VALUES ('104', 'Evan');''') 
c.execute('''INSERT INTO customers (customer_id, customer_name) VALUES ('105', 'Toby');''') 


# Create table
c.execute('''DROP TABLE IF EXISTS orders;''')

c.execute('''CREATE TABLE orders (
order_id INTEGER ,
customer_id  INTEGER,
order_date DATE,
order_amount INTEGER);''')



# Insert data into table
c.execute('''INSERT INTO orders (order_id, customer_id,order_date,order_amount) VALUES ('401', '103','2012-03-08','4500');''')
c.execute('''INSERT INTO orders (order_id, customer_id,order_date,order_amount) VALUES ('402', '101','2012-09-15','3650');''')
c.execute('''INSERT INTO orders (order_id, customer_id,order_date,order_amount) VALUES ('403', '102','2012-06-27','4800');''')

conn.commit()

# Get DataFrame
conn = sqlite3.connect('test2_database') 
customers = pd.read_sql_query ('''SELECT * FROM customers''',conn)
orders=pd.read_sql_query ('''SELECT * FROM orders''',conn)

# %%
# Write Your Code Here
mysql(''' 
select customers.customer_name, orders.customer_id
from customers
left join orders on customers.customer_id = orders.customer_id
group by customers.customer_id

''')
# Out:
#   customer_name  customer_id
# 0          Liam        101.0
# 1          Josh        102.0
# 2          Sean        103.0
# 3          Evan          NaN
# 4          Toby          NaN

# %% [markdown]
# ## 4. From the following dataframe, write a SQL query to find all the duplicate emails of employees keeping the unique email with the lowest employee id. Return employee id and duplicate emails.
#
# Return employee id and unique emails.(Optional)
#
# **Create DataFrame : employees**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Expected Output:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **(Optional) Expected Output:**
#
# ![image.png](data:image/png;base64,...)

# %%
# Install SQlite & Pandasql
# !pip install db-sqlite3
# !pip install pandasql

# Importing Libraries
import pandas as pd
import sqlite3
from pandasql import sqldf
mysql = lambda q: sqldf(q, globals())


# Connection to DataBase
conn = sqlite3.connect('test2_database') 
c = conn.cursor()


# Create table
c.execute('''
          DROP TABLE IF EXISTS employees;''')

c.execute('''CREATE TABLE employees (
[employee_id] INTEGER,
[employee_name]  VARCHAR,
[email_id] VARCHAR);''')


          
# Insert data into table          
c.execute('''INSERT INTO employees (employee_id,employee_name, email_id) VALUES ('101','Liam Alton', 'li.al@abc.com');''') 
c.execute('''INSERT INTO employees (employee_id,employee_name, email_id) VALUES ('102','Josh Day', 'jo.da@abc.com');''') 
c.execute('''INSERT INTO employees (employee_id,employee_name, email_id) VALUES ('103','Sean Mann', 'se.ma@abc.com');''') 	
c.execute('''INSERT INTO employees (employee_id,employee_name, email_id) VALUES ('104','Evan Blake', 'ev.bl@abc.com');''') 
c.execute('''INSERT INTO employees (employee_id,employee_name, email_id) VALUES ('105','Toby Scott', 'jo.da@abc.com');''') 

conn.commit()

# Get DataFrame
conn = sqlite3.connect('test2_database') 
employees = pd.read_sql_query ('''SELECT * FROM employees''',conn)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: db-sqlite3 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Requirement already satisfied: db in /usr/local/lib/python3.7/dist-packages (from db-sqlite3) (0.1.1)
# Requirement already satisfied: antiorm in /usr/local/lib/python3.7/dist-packages (from db->db-sqlite3) (1.2.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandasql in /usr/local/lib/python3.7/dist-packages (0.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.21.6)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.4.37)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandasql) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->pandasql) (4.11.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->pandasql) (1.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->pandasql) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->pandasql) (4.1.1)

# %%
# Write Your Code Here
mysql('''select count(email_id) , employee_id, employee_name from employees''')
# Out:
#    count(email_id)  employee_id employee_name
# 0                5          105    Toby Scott

# %%
#(Optional)
# Write Your Code Here

# %% [markdown]
# # **MATH**

# %% [markdown]
# ## 5. Given v = i - 2j + 2k and u = 4i - 3k, Find
# ## --the component of v in the direction of u,
#
# ## --the projection of v in the direction of u,
#
# ## --the resolution of v into components parallel and perpendicular to u.
#
# **Solve this on a piece of paper and submit the image.**

# %% [markdown]
# Upload your answer here.

# %% [markdown]
# ![WhatsApp Image 2022-06-29 at 3.26.38 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 6. Find a vector that is orthogonal to the plane containing the points P=(3,0,1), Q=(4,−2,1) and R=(5,3,−1).
#
# **Solve this on a piece of paper and submit the image.**

# %% [markdown]
# Upload your answer here.

# %% [markdown]
# ![WhatsApp Image 2022-06-29 at 3.26.37 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **MACHINE LEARNING**

# %% [markdown]
# ## 7. Why we can’t do a classification problem using Regression?

# %% [markdown]
# Write your answer here.

# %% [markdown]
# Classification problem gives predicted output in categorical format. In regression we must have to prepare the dataset first with all numerical values to feed it to the machine learning model. Thus the resultant prediction is also in the numerical while in case of classification we have to classify thing in categories and thus it gives categorical predictions which cannot be fitted in the regression models

# %% [markdown]
# ## 8. How do you treat heteroscedasticity in regression? What causes Heteroscedasticity and how to fix it?

# %% [markdown]
# Write your answer here.

# %% [markdown]
# Heterosedasticity can be defined as the unequal distribution of residuals accross the data. It is present when the size of the error term accross the values of an independent variables is different.
# It can be caused due to Outliers present in the data or removal of the relevent feature from the data.
# we can treat it by Log transformation of features or outlier treatments or we can try polynomial fit.
